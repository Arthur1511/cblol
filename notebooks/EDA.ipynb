# %%
import pandas as pd

# %load_ext kedro.ipython
pd.set_option('display.max_columns', 100)
# Out:
# [02/06/23 12:15:53] INFO     Resolved project path as: c:\Users\arthu\Documents\DEV\cblol.          ]8;id=830597;file://c:\Users\arthu\.conda\envs\kedro-env\lib\site-packages\kedro\ipython\__init__.py\__init__.py]8;;\:]8;id=597620;file://c:\Users\arthu\.conda\envs\kedro-env\lib\site-packages\kedro\ipython\__init__.py#132\132]8;;\
#                              To set a different path, run '%reload_kedro <project_root>'
# [02/06/23 12:16:03] INFO     Kedro project cblol                                                    ]8;id=638027;file://c:\Users\arthu\.conda\envs\kedro-env\lib\site-packages\kedro\ipython\__init__.py\__init__.py]8;;\:]8;id=921436;file://c:\Users\arthu\.conda\envs\kedro-env\lib\site-packages\kedro\ipython\__init__.py#101\101]8;;\
# ...

# %%
df = catalog.load('model_input_table')
df
# Out:
# [02/06/23 12:22:48] INFO     Loading data from 'model_input_table' (ParquetDataSet)...          ]8;id=142707;file://c:\Users\arthu\.conda\envs\kedro-env\lib\site-packages\kedro\io\data_catalog.py\data_catalog.py]8;;\:]8;id=467596;file://c:\Users\arthu\.conda\envs\kedro-env\lib\site-packages\kedro\io\data_catalog.py#343\343]8;;\
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>teamname</th>
#       <th>gamelength</th>
#       <th>result</th>
#       <th>game</th>
#       <th>patch</th>
#       <th>playoffs</th>
#       <th>ckpm</th>
#       <th>side</th>
#       <th>ban1</th>
#       <th>ban2</th>
#       <th>ban3</th>
#       <th>ban4</th>
# ...

# %%
def _to_category(x: pd.Series) -> pd.Series:
    """Preprocesses the data for teams.

    Args:
        df (pd.Series): raw data

    Returns:
        Preprocessed data, with column transformed to category.
    """ 
    return x.astype('category')

# %%
cat_cols = df.select_dtypes(include=['object']).columns.append(pd.Index(['teamname', 'patch']))
# df[cat_cols].astype('category').info()
list(df.select_dtypes(include=['object']).columns.append(pd.Index(['teamname', 'patch'])))
# Out:
# ['gameid', 'teamname', 'side', 'ban1', 'ban2', 'ban3', 'ban4', 'ban5', 'teamname', 'patch']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 486 entries, 0 to 485
# Data columns (total 99 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Unnamed: 0                486 non-null    int64
#  1   gameid                    486 non-null    object
#  2   teamname                  486 non-null    object
#  3   gamelength                486 non-null    int64
#  4   result                    486 non-null    int64
#  5   game                      486 non-null    int64
#  6   patch                     486 non-null    float64
#  7   playoffs                  486 non-null    int64
#  8   ckpm                      486 non-null    float64
#  9   side                      486 non-null    object
#  10  ban1                      486 non-null    object
#  11  ban2                      486 non-null    object
#  12  ban3                      486 non-null    object
# ...

# %%
for c in df.columns:
    print(f"- {c}")
# Out:
# - teamname
# - gamelength
# - result
# - game
# - patch
# - playoffs
# - ckpm
# - side
# - ban1
# - ban2
# - ban3
# - ban4
# - ban5
# - teamkills
# - teamdeaths
# - firstblood
# - team kpm
# - firstdragon
# - dragons
# - opp_dragons
# - elementaldrakes
# - opp_elementaldrakes
# - infernals
# - mountains
# - clouds
# - oceans
# - chemtechs
# - hextechs
# - elders
# - opp_elders
# - firstherald
# - heralds
# - opp_heralds
# - firstbaron
# - barons
# - opp_barons
# - firsttower
# - towers
# - opp_towers
# - firstmidtower
# - firsttothreetowers
# - turretplates
# - opp_turretplates
# - inhibitors
# - opp_inhibitors
# - damagetochampions
# - dpm
# - damagetakenperminute
# - damagemitigatedperminute
# - wardsplaced
# - wpm
# - wardskilled
# - wcpm
# - controlwardsbought
# - visionscore
# - vspm
# - totalgold
# - earnedgold
# - earned gpm
# - goldspent
# - gspd
# - minionkills
# - monsterkills
# - cspm
# - goldat10
# - xpat10
# - csat10
# - opp_goldat10
# - opp_xpat10
# - opp_csat10
# ...
